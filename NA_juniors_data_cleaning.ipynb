# %% [markdown]
# This is a preliminary cleaning and splitting of the data. I want to work with the data as a whole as well as certain subsets, such as only players who were drafted.

# %%
 # %matplotlib notebook

# %%
#Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
#Import CSV
juniors_df=pd.read_csv('data_sets/na_juniors_99to19.csv')
juniors_df.head()
# Out:
#   LEAGUE                 PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP  G  A  \
# 0    WHL           100056/tye-hand        D    2013    18.252778  31  0  2
# 1    OHL      100141/sean-thompson        F    2002    18.625000  38  0  4
# 2    OHL      100141/sean-thompson        F    2003    19.625000  61  6  5
# 3    OHL      100141/sean-thompson        F    2004    20.625000  38  6  5
# 4   USHL  100151/stanislav-dzakhov        F    2012    19.497222  44  9  5
#
#    TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0   2  0.060000  ...             1      31              1              0
# 1   4  0.110000  ...             1      38              0              1
# 2  11  0.180328  ...             2      99              0              1
# 3  11  0.289474  ...             3     137              0              1
# 4  14  0.318182  ...             1      44              0              0
#
#           DOB DY_STATUS SHOOTS DRAFTED NHL_PPG  NHL_GP
# ...

# %%
# Drop columns that will not be used & duplicates
juniors_df=juniors_df.drop(['DOB'],axis=1)

juniors_df=juniors_df.drop_duplicates(keep='last', subset='PLAYER_ID')

# %%
#player count of all players which we have juniors hockey data for 
players = juniors_df['PLAYER_ID'].count()
print(f'Total unique players: {players}')
# Out:
# Total unique players: 13997

# %%
# Create a dummy variable for whether or not a player has made it to NHL level
juniors_df['NHL_DV'] = 1
juniors_df.NHL_DV[juniors_df.NHL_GP == 0] = 0
juniors_df.head(50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     LEAGUE                           PLAYER_ID POSITION  SEASON  AGE_SEPT_15  \
# 0      WHL                     100056/tye-hand        D    2013    18.252778
# 3      OHL                100141/sean-thompson        F    2004    20.625000
# 5     USHL            100151/stanislav-dzakhov        F    2013    20.497222
# 7    QMJHL              100165/owen-bennington        F    2015    20.444444
# 9    QMJHL                100224/tomas-pavelka        D    2013    20.294444
# 10   QMJHL         100294/alexandre-sansregret        F    2011    17.822222
# ...

# %%
# create a unique DF for only players who are drafted
drafted_df = juniors_df[juniors_df['DRAFTED']=='Yes']
drafted_df.head()
# Out:
#     LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G  \
# 31     WHL  100577/richard-nejezchleb        F    2015    21.369444  49  20
# 53   QMJHL        100867/jan-kostalek        D    2015    20.577778  57   7
# 81     OHL     101221/dominik-kubalik        F    2014    19.066667  59  18
# 86     WHL          10123/denis-rehak        D    2004    19.336111  25   0
# 100   USHL       101430/nathan-walker        F    2013    19.605556  29   7
#
#       A  TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  \
# 31   31  51  1.040816  ...             3     150              0
# 53   36  43  0.754386  ...             3     160              0
# 81   11  29  0.491525  ...             2     126              0
# 86    3   3  0.120000  ...             1      25              1
# 100  20  27  0.931034  ...             1      29              1
#
#      MIN_3_SEASONS  DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# ...

# %%
# we have data for 2810 players who were drafted out of a total of pool of 13,997 players
drafted_players = drafted_df['PLAYER_ID'].nunique()
print(f'Total unique drafted players: {drafted_players}')
# Out:
# Total unique drafted players: 2810

# %%
#create unique df for each league
ohl_df=juniors_df[juniors_df['LEAGUE']=='OHL']

whl_df=juniors_df[juniors_df['LEAGUE']=='WHL']

ushl_df=juniors_df[juniors_df['LEAGUE']=='USHL']

qmjhl_df=juniors_df[juniors_df['LEAGUE']=='QMJHL']

# %%
# save each subset of data to a CSV 

juniors_df.to_csv('data_sets/juniors_data.csv', index=False)
drafted_df.to_csv('data_sets/drafted_data.csv', index=False)
ohl_df.to_csv('data_sets/ohl_data.csv', index=False)
ushl_df.to_csv('data_sets/ushl_data.csv', index=False)
whl_df.to_csv('data_sets/whl_data.csv', index=False)
qmjhl_df.to_csv('data_sets/qmjhl_data.csv', index=False)
