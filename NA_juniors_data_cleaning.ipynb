# %% [markdown]
# This is a preliminary cleaning and splitting of the data. I want to work with the data as a whole as well as certain subsets, such as only players who were drafted.

# %%
 # %matplotlib notebook

# %%
#Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
#Import CSV
juniors_df=pd.read_csv('na_juniors_99to19.csv')
juniors_df.head()
# Out:
#   LEAGUE                 PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP  G  A  \
# 0    WHL           100056/tye-hand        D    2013    18.252778  31  0  2
# 1    OHL      100141/sean-thompson        F    2002    18.625000  38  0  4
# 2    OHL      100141/sean-thompson        F    2003    19.625000  61  6  5
# 3    OHL      100141/sean-thompson        F    2004    20.625000  38  6  5
# 4   USHL  100151/stanislav-dzakhov        F    2012    19.497222  44  9  5
#
#    TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0   2  0.060000  ...             1      31              1              0
# 1   4  0.110000  ...             1      38              0              1
# 2  11  0.180328  ...             2      99              0              1
# 3  11  0.289474  ...             3     137              0              1
# 4  14  0.318182  ...             1      44              0              0
#
#           DOB DY_STATUS SHOOTS DRAFTED NHL_PPG  NHL_GP
# 0  1995-06-14        DY      L      No     0.0       0
# 1  1984-01-31        DY      L      No     0.0       0
# 2  1984-01-31      DY+1      L      No     0.0       0
# 3  1984-01-31      DY+2      L      No     0.0       0
# 4  1993-03-16      DY+1      R      No     0.0       0
#
# [5 rows x 21 columns]

# %%
# Drop columns that will not be used & duplicates
juniors_df=juniors_df.drop(['DOB'],axis=1)

juniors_df=juniors_df.drop_duplicates(keep='last', subset='PLAYER_ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-4336a69ab3cc> in <module>
#       1 # Drop columns that will not be used & duplicates
# ----> 2 juniors_df=juniors_df.drop(['DOB'],axis=1)
#       3
#       4 juniors_df=juniors_df.drop_duplicates(keep='last', subset='PLAYER_ID')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['DOB'] not found in axis"

# %%
#player count and unique, these are the same because duplicates were dropped except for the last season in juniors
juniors_df['PLAYER_ID'].nunique()
# 13,997 Unique players
juniors_df['PLAYER_ID'].count()
#  35,251 entries
# Out:
# 35251

# %%
# create a unique DF for only players who are drafted

drafted_df = juniors_df[juniors_df['DRAFTED']=='Yes']
drafted_df.head()
# Out:
#    LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G  \
# 29    WHL  100577/richard-nejezchleb        F    2013    19.369444  35  11
# 30    WHL  100577/richard-nejezchleb        F    2014    20.369444  66  32
# 31    WHL  100577/richard-nejezchleb        F    2015    21.369444  49  20
# 51  QMJHL        100867/jan-kostalek        D    2013    18.577778  48   5
# 52  QMJHL        100867/jan-kostalek        D    2014    19.577778  55   5
#
#      A  TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 29  13  24  0.685714  ...             1      35              0              1
# 30  25  57  0.863636  ...             2     101              0              1
# 31  31  51  1.040816  ...             3     150              0              1
# 51  13  18  0.375000  ...             1      48              0              1
# 52  22  27  0.490909  ...             2     103              0              1
#
#            DOB DY_STATUS SHOOTS DRAFTED NHL_PPG  NHL_GP
# 29  1994-05-02      DY+1      L     Yes     0.0       0
# 30  1994-05-02      DY+2      L     Yes     0.0       0
# 31  1994-05-02      DY+3      L     Yes     0.0       0
# 51  1995-02-17        DY      R     Yes     0.0       0
# 52  1995-02-17      DY+1      R     Yes     0.0       0
#
# [5 rows x 21 columns]

# %%
# we have data for 2810 players who were drafted out of a total of pool of 13,997 players
drafted_df['PLAYER_ID'].nunique()
# Out:
# 2810

# %%
#
# Out:
#             SEASON  AGE_SEPT_15           GP            G            A  \
# count  8597.000000  8597.000000  8597.000000  8597.000000  8597.000000
# mean   2008.399674    19.151417    56.122019    15.113644    24.328603
# std       5.959678     1.216735    14.867912    12.613099    16.251229
# min    1996.000000    15.858333     1.000000     0.000000     0.000000
# 25%    2003.000000    18.266667    52.000000     5.000000    11.000000
# 50%    2008.000000    19.225000    61.000000    12.000000    22.000000
# 75%    2013.000000    20.161111    66.000000    23.000000    35.000000
# max    2019.000000    21.705556    81.000000    74.000000   115.000000
#
#                 TP          PPG    SEASON_NO  SEASON_>20GP       CUM_GP  \
# count  8597.000000  8597.000000  8597.000000   8597.000000  8597.000000
# mean     39.443294     0.686249     2.292311      2.160405   128.519949
# std      26.960646     0.420776     1.178488      1.211940    74.847453
# min       1.000000     0.020000     1.000000      0.000000     1.000000
# 25%      17.000000     0.344828     1.000000      1.000000    62.000000
# 50%      35.000000     0.628571     2.000000      2.000000   122.000000
# 75%      57.000000     0.961538     3.000000      3.000000   186.000000
# max     186.000000     2.952381     6.000000      6.000000   357.000000
#
#        ONLY_1_SEASON  MIN_3_SEASONS      NHL_PPG       NHL_GP
# count    8597.000000    8597.000000  8597.000000  8597.000000
# mean        0.049436       0.801326     0.111267    99.910318
# std         0.216789       0.399025     0.191736   211.741603
# min         0.000000       0.000000     0.000000     0.000000
# 25%         0.000000       1.000000     0.000000     0.000000
# 50%         0.000000       1.000000     0.000000     0.000000
# 75%         0.000000       1.000000     0.186667    75.000000
# max         1.000000       1.000000     3.000000  1249.000000

# %%
# #create unique df for each league
# ohl_players=juniors_df[juniors_df['LEAGUE']=='OHL']

# whl_players=juniors_df[juniors_df['LEAGUE']=='WHL']

# ushl_players=juniors_df[juniors_df['LEAGUE']=='USHL']

# qmjhl_players=juniors_df[juniors_df['LEAGUE']=='QMJHL']

# %%
# 
avg_gp = drafted_df['CUM_GP'].mean()
avg_nhl_gp = drafted_df['NHL_GP'].mean()
print(f'Average Juniors Games Played: {avg_gp}')
print(f'Average NHL Games Played: {avg_nhl_gp}')
# Out:
# Average Juniors Games Played: 128.5199488193556
# Average NHL Games Played: 99.91031755263464

# %%
#drafted only Df
