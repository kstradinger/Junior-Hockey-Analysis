# %% [markdown]
# Using KNN to predict whether or not a drafted player will reach the NHL level

# %%
# Dependencies
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# %%
# Load in data
df = pd.read_csv('data_sets/drafted_data.csv')
df.head()
# Out:
#   LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G   A  \
# 0    WHL  100577/richard-nejezchleb        F    2015    21.369444  49  20  31
# 1  QMJHL        100867/jan-kostalek        D    2015    20.577778  57   7  36
# 2    OHL     101221/dominik-kubalik        F    2014    19.066667  59  18  11
# 3    WHL          10123/denis-rehak        D    2004    19.336111  25   0   3
# 4   USHL       101430/nathan-walker        F    2013    19.605556  29   7  20
#
#    TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0  51  1.040816  ...             3     150              0              1
# 1  43  0.754386  ...             3     160              0              1
# 2  29  0.491525  ...             2     126              0              0
# 3   3  0.120000  ...             1      25              1              0
# 4  27  0.931034  ...             1      29              1              0
#
#    DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# 0       DY+3      L     Yes  0.000000       0       0
# 1       DY+2      R     Yes  0.000000       0       0
# 2       DY+1      L     Yes  0.000000       0       0
# 3       DY+1      L     Yes  0.000000       0       0
# 4       DY+1      L     Yes  0.166667      12       1
#
# [5 rows x 21 columns]

# %%
# dropping non-numeric columns
df = df.drop(['Un'], axis=1)
df.head()

# %%
# split into inputs and outputs
outcomes = df['NHL_DV']
outcomes.head()

input_factors = df.drop(['NHL_DV'], axis = 1)
input_factors.head()
# Out:
#   LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G   A  \
# 0    WHL  100577/richard-nejezchleb        F    2015    21.369444  49  20  31
# 1  QMJHL        100867/jan-kostalek        D    2015    20.577778  57   7  36
# 2    OHL     101221/dominik-kubalik        F    2014    19.066667  59  18  11
# 3    WHL          10123/denis-rehak        D    2004    19.336111  25   0   3
# 4   USHL       101430/nathan-walker        F    2013    19.605556  29   7  20
#
#    TP       PPG  SEASON_NO  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  \
# 0  51  1.040816          3             3     150              0
# 1  43  0.754386          3             3     160              0
# 2  29  0.491525          2             2     126              0
# 3   3  0.120000          1             1      25              1
# 4  27  0.931034          1             1      29              1
#
#    MIN_3_SEASONS DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP
# 0              1      DY+3      L     Yes  0.000000       0
# 1              1      DY+2      R     Yes  0.000000       0
# 2              0      DY+1      L     Yes  0.000000       0
# 3              0      DY+1      L     Yes  0.000000       0
# 4              0      DY+1      L     Yes  0.166667      12

# %%
# Train/test Split
input_train, input_test, output_train, output_test = train_test_split(input_factors, outcomes, random_state=42, 
                                                                      stratify=outcomes)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

input_scaler = StandardScaler().fit(input_train.values.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c717b7666318> in <module>
#       3 # Create a StandardScater model and fit it to the training data
#       4
# ----> 5 input_scaler = StandardScaler().fit(input_train.values.reshape(-1, 1))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     667         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     668                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES,
# --> 669                         force_all_finite='allow-nan')
#     670
#     671         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'USHL'
