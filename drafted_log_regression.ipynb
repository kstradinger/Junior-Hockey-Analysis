# %%
#  Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
# Load in data
df = pd.read_csv('data_sets/drafted_data.csv')
df.head()
# Out:
#   LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G   A  \
# 0    WHL  100577/richard-nejezchleb        F    2015    21.369444  49  20  31
# 1  QMJHL        100867/jan-kostalek        D    2015    20.577778  57   7  36
# 2    OHL     101221/dominik-kubalik        F    2014    19.066667  59  18  11
# 3    WHL          10123/denis-rehak        D    2004    19.336111  25   0   3
# 4   USHL       101430/nathan-walker        F    2013    19.605556  29   7  20
#
#    TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0  51  1.040816  ...             3     150              0              1
# 1  43  0.754386  ...             3     160              0              1
# 2  29  0.491525  ...             2     126              0              0
# 3   3  0.120000  ...             1      25              1              0
# 4  27  0.931034  ...             1      29              1              0
#
#    DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# 0       DY+3      L     Yes  0.000000       0       0
# 1       DY+2      R     Yes  0.000000       0       0
# 2       DY+1      L     Yes  0.000000       0       0
# 3       DY+1      L     Yes  0.000000       0       0
# 4       DY+1      L     Yes  0.166667      12       1
#
# [5 rows x 21 columns]

# %%
# Function to convert League from string into int
def league_int(x):
    if x.LEAGUE == 'WHL':
        return 0
    elif x.LEAGUE == 'QMJHL':
        return 1
    elif x.LEAGUE == 'OHL':
        return 2
    elif x.LEAGUE == 'USHL':
        return 3

# %%
#apply funct to set and show headto see league is now int
df['LEAGUE'] = df.apply(league_int, axis=1)
df.head()
# Out:
#    LEAGUE                  PLAYER_ID POSITION  SEASON  AGE_SEPT_15  GP   G  \
# 0       0  100577/richard-nejezchleb        F    2015    21.369444  49  20
# 1       1        100867/jan-kostalek        D    2015    20.577778  57   7
# 2       2     101221/dominik-kubalik        F    2014    19.066667  59  18
# 3       0          10123/denis-rehak        D    2004    19.336111  25   0
# 4       3       101430/nathan-walker        F    2013    19.605556  29   7
#
#     A  TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0  31  51  1.040816  ...             3     150              0              1
# 1  36  43  0.754386  ...             3     160              0              1
# 2  11  29  0.491525  ...             2     126              0              0
# 3   3   3  0.120000  ...             1      25              1              0
# 4  20  27  0.931034  ...             1      29              1              0
#
#    DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# 0       DY+3      L     Yes  0.000000       0       0
# 1       DY+2      R     Yes  0.000000       0       0
# 2       DY+1      L     Yes  0.000000       0       0
# 3       DY+1      L     Yes  0.000000       0       0
# 4       DY+1      L     Yes  0.166667      12       1
#
# [5 rows x 21 columns]

# %%
# Create a function to coonvert position string to int
def position_int(x):
    if x.POSITION == 'F':
        return 0
    elif x.POSITION == 'D':
        return 1

# %%
# Apply position conversion function adn display head to show it worked properly
df['POSITION'] = df.apply(position_int, axis=1)
df.head()
# Out:
#    LEAGUE                  PLAYER_ID  POSITION  SEASON  AGE_SEPT_15  GP   G  \
# 0       0  100577/richard-nejezchleb         0    2015    21.369444  49  20
# 1       1        100867/jan-kostalek         1    2015    20.577778  57   7
# 2       2     101221/dominik-kubalik         0    2014    19.066667  59  18
# 3       0          10123/denis-rehak         1    2004    19.336111  25   0
# 4       3       101430/nathan-walker         0    2013    19.605556  29   7
#
#     A  TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0  31  51  1.040816  ...             3     150              0              1
# 1  36  43  0.754386  ...             3     160              0              1
# 2  11  29  0.491525  ...             2     126              0              0
# 3   3   3  0.120000  ...             1      25              1              0
# 4  20  27  0.931034  ...             1      29              1              0
#
#    DY_STATUS SHOOTS DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# 0       DY+3      L     Yes  0.000000       0       0
# 1       DY+2      R     Yes  0.000000       0       0
# 2       DY+1      L     Yes  0.000000       0       0
# 3       DY+1      L     Yes  0.000000       0       0
# 4       DY+1      L     Yes  0.166667      12       1
#
# [5 rows x 21 columns]

# %%
# define function to convert shoots from string to int
def shoots_int(x):
    if x.SHOOTS == 'L':
        return 0
    elif x.SHOOTS == 'R':
        return 1

# %%
df['SHOOTS'] = df.apply(shoots_int, axis=1)
df.head()
# Out:
#    LEAGUE                  PLAYER_ID  POSITION  SEASON  AGE_SEPT_15  GP   G  \
# 0       0  100577/richard-nejezchleb         0    2015    21.369444  49  20
# 1       1        100867/jan-kostalek         1    2015    20.577778  57   7
# 2       2     101221/dominik-kubalik         0    2014    19.066667  59  18
# 3       0          10123/denis-rehak         1    2004    19.336111  25   0
# 4       3       101430/nathan-walker         0    2013    19.605556  29   7
#
#     A  TP       PPG  ...  SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  \
# 0  31  51  1.040816  ...             3     150              0              1
# 1  36  43  0.754386  ...             3     160              0              1
# 2  11  29  0.491525  ...             2     126              0              0
# 3   3   3  0.120000  ...             1      25              1              0
# 4  20  27  0.931034  ...             1      29              1              0
#
#    DY_STATUS SHOOTS  DRAFTED   NHL_PPG  NHL_GP  NHL_DV
# 0       DY+3    0.0      Yes  0.000000       0       0
# 1       DY+2    1.0      Yes  0.000000       0       0
# 2       DY+1    0.0      Yes  0.000000       0       0
# 3       DY+1    0.0      Yes  0.000000       0       0
# 4       DY+1    0.0      Yes  0.166667      12       1
#
# [5 rows x 21 columns]

# %%
# split outcomes into independent Df
outcomes = df['NHL_DV']
outcomes.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: NHL_DV, dtype: int64

# %%
# Create input factors w/o outcomes, drop ID
input_factors = df.drop(['NHL_DV', 'PLAYER_ID','DY_STATUS','DRAFTED','SEASON','NHL_PPG','NHL_GP'], axis = 1)
input_factors.head()
# Out:
#    LEAGUE  POSITION  AGE_SEPT_15  GP   G   A  TP       PPG  SEASON_NO  \
# 0       0         0    21.369444  49  20  31  51  1.040816          3
# 1       1         1    20.577778  57   7  36  43  0.754386          3
# 2       2         0    19.066667  59  18  11  29  0.491525          2
# 3       0         1    19.336111  25   0   3   3  0.120000          1
# 4       3         0    19.605556  29   7  20  27  0.931034          1
#
#    SEASON_>20GP  CUM_GP  ONLY_1_SEASON  MIN_3_SEASONS  SHOOTS
# 0             3     150              0              1     0.0
# 1             3     160              0              1     1.0
# 2             2     126              0              0     0.0
# 3             1      25              1              0     0.0
# 4             1      29              1              0     0.0

# %%
# Drop NaN and infinite numbers from set
df.replace([np.inf, -np.inf], np.nan).dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5b78e0065a57> in <module>
#       1 # Drop NaN and infinite numbers from set
# ----> 2 df.replace([np.inf, -np.inf], np.nan).dropna()
#       3
#
# NameError: name 'np' is not defined

# %%
# Assign X (data) and y (target)
X = input_factors
y = outcomes
print(X.shape, y.shape)
# Out:
# (2810, 14) (2810,)

# %%
# split data into test/train
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# import llogistic reg from sklean
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# run regression
classifier.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-479d212a1fc4> in <module>
#       1 # run regression
# ----> 2 classifier.fit(X_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
